# %%
import pandas as pd

# %%
chromo_df = pd.read_pickle('chromo_db_filtered.pkl')
overlap_df = pd.read_pickle('percent_overlap_df.pkl')

# %%
chromo_df.dropna(inplace=True)

# %%
chromo_df.loc[chromo_df['Solvent_iupac']=='chloroform']
# Out:
#                                              Chromophore    Solvent  \
# 0      CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...  ClC(Cl)Cl
# 95                   O=C1NC(=O)c2ccc(N3CCCCC3)c3cccc1c23  ClC(Cl)Cl
# 96                   O=C1NC(=O)c2ccc(N3CCOCC3)c3cccc1c23  ClC(Cl)Cl
# 239    CCCCCCCCCCN1C(=O)c2cc(NCCCOCCO)c3c4c(cc(NCCCOC...  ClC(Cl)Cl
# 240    CC(=O)OCCOCCN1C(=O)c2cc(NCCOCCO)c3c4c(cc(NCCOC...  ClC(Cl)Cl
# ...                                                  ...        ...
# 13405                            c1cc2c3cscc3c3ccsc3c2s1  ClC(Cl)Cl
# 13406              CCCCCCc1sc(CCCCCC)c2c3ccsc3c3sccc3c12  ClC(Cl)Cl
# 13407  CCCCCCCCCCCCc1sc(CCCCCCCCCCCC)c2c3ccsc3c3sccc3c12  ClC(Cl)Cl
# 13408  CCCCCCCCCCCCc1sc(CCCCCC)c2c3cc(CCCCCC)sc3c3sc(...  ClC(Cl)Cl
# 13409              CCCCCCc1cc2c3cscc3c3cc(CCCCCC)sc3c2s1  ClC(Cl)Cl
#
#        Absorption max (nm)  Emission max (nm) Solvent_iupac
# 0                    526.0              535.0    chloroform
# 95                   414.0              517.0    chloroform
# 96                   394.0              504.0    chloroform
# 239                  609.0              640.0    chloroform
# 240                  610.0              640.0    chloroform
# ...                    ...                ...           ...
# 13405                360.0              395.0    chloroform
# 13406                383.0              425.0    chloroform
# 13407                383.0              425.0    chloroform
# 13408                373.0              423.0    chloroform
# 13409                393.0              442.0    chloroform
#
# [1199 rows x 5 columns]

# %%
overlap_df.dropna()
# Out:
#                                                    Chromo A  \
# 0         CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...
# 1         CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...
# 4         CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...
# 5         CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...
# 6         CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...
# ...                                                     ...
# 21198848  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...
# 21198849  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...
# 21198850  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...
# 21198851  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...
# 21198854  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...
#
#                                                    Chromo B  A: abs (nm)  \
# 0                       O=C1NC(=O)c2ccc(N3CCCCC3)c3cccc1c23        526.0
# 1                       O=C1NC(=O)c2ccc(N3CCOCC3)c3cccc1c23        526.0
# 4         CCCCCCCCCCN1C(=O)c2cc(NCCCOCCO)c3c4c(cc(NCCCOC...        526.0
# 5         CC(=O)OCCOCCN1C(=O)c2cc(NCCOCCO)c3c4c(cc(NCCOC...        526.0
# 6         COCCOCCOCCN1C(=O)c2cc(NCCOCCO)c3c4c(cc(NCCOCCO...        526.0
# ...                                                     ...          ...
# 21198848       N#Cc1c(N2CCCCC2)cc(-c2ccccc2)c2c1Cc1ccccc1-2        344.0
# 21198849  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1Cc1cccc...        344.0
# 21198850  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccccc3c2)c2c1Cc1cccc...        344.0
# 21198851  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...        344.0
# 21198854  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1C(=O)c1...        344.0
#
#           B: em (nm)     Solvent  Percent Overlap
# 0              517.0  chloroform     6.525526e-01
# 1              504.0  chloroform     2.712789e-01
# 4              640.0  chloroform     1.189909e-08
# 5              640.0  chloroform     1.189909e-08
# 6              640.0  chloroform     1.189909e-08
# ...              ...         ...              ...
# 21198848       449.0     oxolane     1.520510e-07
# 21198849       451.0     oxolane     8.676563e-08
# 21198850       465.0     oxolane     1.469020e-09
# 21198851       481.0     oxolane     7.236394e-12
# 21198854       460.0     oxolane     6.565336e-09
#
# [17812124 rows x 6 columns]
