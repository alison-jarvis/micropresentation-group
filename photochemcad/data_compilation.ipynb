# %%
# Imports 
import os
import re
import pickle

# %%
# Get absorption and emission file paths
def get_absorption_emission_files(directory):
    abs_files, ems_files = [], []
    for fp in os.listdir(directory):
        match = re.match(r'^(.*?)\(.*\)(.*)$', fp)
        if match:
            compound_solvent, file_type = match.groups()
            if file_type == '.abs.txt':
                abs_files.append((compound_solvent, fp))
            elif file_type == '.ems.txt':
                ems_files.append((compound_solvent, fp))
    return abs_files, ems_files

# Read in the text file and return wavelength and intensity
def read_txt_file(txt_file_path):
    wavelengths, intensities = [], []
    with open(txt_file_path, 'r') as file:
        lines = file.readlines()
        for i, line in enumerate(lines):
            if i > 0:
                line_split = line.split()
                if len(line_split) > 0:
                    wavelengths.append(float(line_split[0]))
                    intensities.append(float(line_split[1]))
    return wavelengths, intensities

def match_absorption_emission(directory, abs_files, ems_files):
    ems_dict = dict(ems_files)
    combined = {
        key: {'absorption': val1, 'emission': ems_dict.get(key)}
        for key, val1 in abs_files if key in ems_dict}
    wavelengths_and_intensities = dict()
    for compound_key in combined.keys():
        abs_wavelength, abs_intensity = read_txt_file(os.path.join(directory, combined[compound_key]['absorption']))
        ems_wavelength, ems_intensity = read_txt_file(os.path.join(directory, combined[compound_key]['emission']))
        compound_dict = dict()
        compound_dict['absorption'] = {'wavelength':abs_wavelength, 'intensity':abs_intensity}
        compound_dict['emission'] = {'wavelength':ems_wavelength, 'intensity':ems_intensity}
        wavelengths_and_intensities[compound_key] = compound_dict
    return wavelengths_and_intensities

# %%
database_path = './Natural Chlorophylls/'
abs_files, ems_files = get_absorption_emission_files(database_path)

# %%
print(ems_files)
# Out:
# [('CHL197_BChl d [E,E]+[P,M], Et2O ', 'CHL197_BChl d [E,E]+[P,M], Et2O (Tamiaki, 2011b).ems.txt'), ('CHL043_Phe a, Pyr ', 'CHL043_Phe a, Pyr (Hindman, 1977).ems.txt'), ('CHL199_BChl e, Pyr ', 'CHL199_BChl e, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL115_PyroPhebide a ME, DCM ', 'CHL115_PyroPhebide a ME, DCM (Dixon, 2005).ems.txt'), ('CHL137_Zn Phe a, C6H6 ', 'CHL137_Zn Phe a, C6H6 (Kobayashi, 2006).ems.txt'), ('CHL156_3-Et Chl e6, DMSO ', 'CHL156_3-Et Chl e6, DMSO (Uliana, 2014).ems.txt'), ('CHL026_Chl d, Pyr ', 'CHL026_Chl d, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL273_BPhe a, Et2O ', 'CHL273_BPhe a, Et2O (Goedheer, 1966).ems.txt'), ('CHL222_Chl c2, Pyr ', 'CHL222_Chl c2, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL029_Ch f, C6H6 ', 'CHL029_Ch f, C6H6 (Kobayashi, 2016).ems.txt'), ('CHL201_BChl e [E,E], THF ', 'CHL201_BChl e [E,E], THF (Kinoshita, 2019).ems.txt'), ('CHL271_BChl g, Pyr ', 'CHL271_BChl g, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL230_Chl C2 phytyl, THF ', 'CHL230_Chl C2 phytyl, THF (Mizoguchi, 2009).ems.txt'), ('CHL202_BChl e [E,E]+[P,E], Et2O ', 'CHL202_BChl e [E,E]+[P,E], Et2O (Tamiaki, 2011b).ems.txt'), ('CHL004_Chl a, C6H6 ', 'CHL004_Chl a, C6H6 (Kobayashi, 2016).ems.txt'), ('CHL155_Chl e6, DMSO ', 'CHL155_Chl e6, DMSO (Uliana, 2014).ems.txt'), ('CHL244_ProtoChllide a, MeOH ', 'CHL244_ProtoChllide a, MeOH (Dietzek, 2006).ems.txt'), ('CHL188_BChl c, Pyr ', 'CHL188_BChl c, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL107_20-Cl Chl a, Ace ', 'CHL107_20-Cl Chl a, Ace (Leupold, 1990).ems.txt'), ('CHL114_PyroPhebide a, DCM ', 'CHL114_PyroPhebide a, DCM (Dixon, 2005).ems.txt'), ('CHL030_Ch f, Et2O ', 'CHL030_Ch f, Et2O (Niedzwiedzki, 2014).ems.txt'), ('CHL232_Phe c1, Ace ', 'CHL232_Phe c1, Ace (Jeffrey, 1972).ems.txt'), ('CHL218_Chl c2, Ace ', 'CHL218_Chl c2, Ace (Jeffrey, 1972).ems.txt'), ('CHL021_Chl d, Et2O ', 'CHL021_Chl d, Et2O (French, 1956).ems.txt'), ('CHL231_Phe c, Et2O ', 'CHL231_Phe c, Et2O (French, 1956).ems.txt'), ('CHL267_BChl b, Pyr ', 'CHL267_BChl b, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL009_Chl a, Pyr ', 'CHL009_Chl a, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL260_BChl a, Pyr ', 'CHL260_BChl a, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL121_3-Et-8-vinyl PyroPhebide a ME, DCM ', 'CHL121_3-Et-8-vinyl PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL262_BChl a, TEA ', 'CHL262_BChl a, TEA (Ratsep, 2011).ems.txt'), ('CHL064_Chl a2, Et2O ', 'CHL064_Chl a2, Et2O (Steglich, 2003).ems.txt'), ('CHL196_BChl d [E,E], THF ', 'CHL196_BChl d [E,E], THF (Kinoshita, 2019).ems.txt'), ('CHL006_Chl a, Et2O ', 'CHL006_Chl a, Et2O (Du, 1998).ems.txt'), ('CHL052_Phe d, Et2O ', 'CHL052_Phe d, Et2O (French, 1956).ems.txt'), ('CHL117_PyroPhebide a ME, DCM ', 'CHL117_PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL014_Chl b, Et2O ', 'CHL014_Chl b, Et2O (Du, 1998).ems.txt'), ('CHL261_BChl a, Tol ', 'CHL261_BChl a, Tol (Dixon, 2005).ems.txt'), ('CHL120_3-Et-7-vinyl PyroPhebide a ME, DCM ', 'CHL120_3-Et-7-vinyl PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL084_Phebide a, EtOH ', 'CHL084_Phebide a, EtOH (Dixon, 2005).ems.txt'), ('CHL073_Phe a2, C6H6 ', 'CHL073_Phe a2, C6H6 (Kobayashi, 2016).ems.txt'), ('CHL205_BChl f [E,M], Et2O ', 'CHL205_BChl f [E,M], Et2O (Tamiaki, 2011b).ems.txt'), ('CHL125_3-CHO PyroPhebide a ME, DCM ', 'CHL125_3-CHO PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL047_Phe b, Et2O ', 'CHL047_Phe b, Et2O (French, 1956).ems.txt'), ('CHL034_Ch f, Pyr ', 'CHL034_Ch f, Pyr (Niedzwiedzki, 2014).ems.txt'), ('CHL215_Chl c, Et2O ', 'CHL215_Chl c, Et2O (French, 1956).ems.txt'), ('CHL017_Chl b, Pyr ', 'CHL017_Chl b, Pyr (Niedzwiedzki, 2010).ems.txt'), ('CHL122_3-Et-12-vinyl PyroPhebide a ME, DCM ', 'CHL122_3-Et-12-vinyl PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL128_3-Et-12-CHO PyroPhebide a ME, DCM ', 'CHL128_3-Et-12-CHO PyroPhebide a ME, DCM (Tamiaki, 2016).ems.txt'), ('CHL013_Chl b, C6H6 ', 'CHL013_Chl b, C6H6 (Kobayashi, 2016).ems.txt'), ('CHL239_ProtoChl a, THF ', 'CHL239_ProtoChl a, TH ...

# %%
waves_n_intensities = match_absorption_emission(database_path, abs_files, ems_files)

# %%
print(len(waves_n_intensities))
# Out:
# 66

# %%
# Save this as a pickle file
pickle.dump(waves_n_intensities, open('./natural_chlorophyll_spectra.pkl', 'wb'))
